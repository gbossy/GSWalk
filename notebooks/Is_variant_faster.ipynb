# %%
from gsw import *

# %%
# %%time
n=10
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(n):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,fast_lst_sq=False))
# Out:
# Finished 'sample_from_ball' in 0.0 secs
# Finished 'orthonormal_basis' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'choose_pivot' in 0.0 secs
# [[ 0.16753183  0.13358966  0.30515742 -0.53483977  0.16507706 -0.08435027
#    0.03519199  0.36301322 -0.1421942 ]
#  [-0.12730428  0.07125895 -0.01083733  0.15595883 -0.02547395 -0.4111186
#   -0.3868348   0.35614932 -0.47225331]
#  [ 0.39204501  0.4400964  -0.03802255 -0.22887156  0.41811013  0.21858934
#    0.12148087 -0.12318906  0.08332715]
#  [ 0.28843969 -0.45227731  0.28437445 -0.21887121  0.34806839 -0.14627059
#    0.07020614 -0.2903133  -0.25407204]
#  [ 0.03683497  0.28579747 -0.28275957 -0.10064653  0.31242527 -0.00850218
#    0.0157541   0.4777129  -0.23310397]
#  [ 0.51423432 -0.09828458 -0.56500928 -0.2770593   0.04529837  0.28333156
#    0.23504898  0.14310844 -0.12822665]
#  [ 0.11322982 -0.0193293   0.1339048   0.0389384  -0.18951585  0.28235332
#   -0.61503611 -0.13822587 -0.34101877]
# ...

# %%
# %%time
n=10
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(n):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,fast_lst_sq=True))
# Out:
# Finished 'sample_from_ball' in 0.0 secs
# Finished 'orthonormal_basis' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'choose_pivot' in 0.0 secs
# A_S:[[ 0.26837605 -0.27522415  0.37818987  0.04366443  0.31767446 -0.15958215
#    0.33551708  0.14515184  0.15065338  0.05698162]
#  [-0.37862561 -0.21984484 -0.05198008  0.19076252  0.15779464  0.12766511
#   -0.07433408  0.49017521 -0.14697613 -0.04029713]
#  [ 0.23826092  0.05714396  0.29892141 -0.40288981 -0.02315781  0.54725406
#    0.17161454  0.37477997 -0.29361802  0.1573372 ]
#  [ 0.1964139  -0.03227945  0.01047533  0.4648679   0.11518111 -0.37955068
#    0.16256154 -0.15101995 -0.07063889 -0.28443652]
#  [-0.42490813 -0.19784543 -0.10645124 -0.03911669 -0.28536898 -0.22995775
#    0.44241625 -0.0672495   0.19374937 -0.23559274]
#  [-0.43543954  0.45760455  0.35212075 -0.34651814  0.542661    0.07951995
#   -0.27199142  0.37181266 -0.04394522 -0.73489919]
# ...

# %%
# %%time
n=5
v=sample_from_ball(n,d=5)
gsw_xs=[]
gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=True,no_matrix_mult=True,flag_issue=True,normal_variant=True,pivot=0,smallest_delta=True,mode='max_coloring'))
# Out:
# Initializing a with -1s
# Initializing b with 1s
# Computing the list of elements that are alive with threshold 1e-12
# x in basis: [0. 0. 0. 0. 0.]
# a: [-1. -1. -1. -1. -1.]
# b: [1. 1. 1. 1. 1.]
#
#  Iteration 0
# Alive and not pivot: [False  True  True  True  True]
# A_S:[[ 0.50500582  0.03649332 -0.04219973  0.38096483 -0.14697725]
#  [-0.25613943  0.06973313  0.14517735 -0.63912093  0.10380225]
#  [-0.04391771 -0.56845843  0.82532728 -0.26648972  0.77127043]
#  [ 0.27620986 -0.38255282 -0.19032155 -0.24943439  0.36399986]
#  [-0.0678809  -0.21368943 -0.41828197  0.00306519  0.37387802]]
# C_S:[[ 2.56389163  1.39188912  0.06158582  0.28631236  0.21567339]
#  [ 5.09390961  4.47886258  0.46255629 -4.14311502  3.83844477]
#  [ 0.26931912  0.07434765  0.6800713  -0.51575829 -0.81555103]
#  [ 0.18658159 -1.14506744  0.34812787 -1.15227993  0.79494601]
#  [ 3.67668933  2.9051625   1.03354129 -2.88357463  3.98875608]]
# ...

# %%
gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=True,no_matrix_mult=True,flag_issue=True,normal_variant=False,pivot=0,smallest_delta=True,mode='max_coloring'))
# Out:
# Finished 'orthonormal_basis' in 0.0 secs
# Initializing a with -1s
# Initializing b with 1s
# Computing the list of elements that are alive with threshold 1e-12
# x in basis: [0. 0. 0. 0. 0.]
# a: [-1. -1. -1. -1. -1.]
# b: [1. 1. 1. 1. 1.]
# Finished 'get_alives' in 0.001 secs
#
#  Iteration 0
# Alive and not pivot: [False  True  True  True  True]
# A_S:[[-0.03544047  0.20114498  0.35238471  0.4203742   0.37161432]
#  [ 0.17726431 -0.28681253 -0.48880526 -0.24162801  0.43578062]
#  [ 0.97882305  0.52114619 -0.72790892 -0.09850049 -0.40566057]
#  [ 0.03062464 -0.21666184  0.01189331  0.08445817 -0.01562438]
#  [ 0.04821238 -0.51754779  0.0973606  -0.16440806 -0.30892016]]
# C_S:[[ 2.28845795  0.71918328  0.9357077  -3.00394302  2.69061407]
#  [ 0.0615588  -0.37811087  0.17038873 -2.29333176 -0.56708946]
#  [ 2.43153284  0.10133238  0.07974559 -5.41787263  3.23725196]
#  [-0.75153282 -1.00246187  0.05957332  7.38983032 -2.77017174]
# ...

# %%
# %%time
n=10
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(n):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=True,flag_issue=False))
# Out:
# Finished 'sample_from_ball' in 0.0 secs
# Finished 'orthonormal_basis' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'choose_pivot' in 0.0 secs
# Finished 'next_direction' in 0.0 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'next_direction' in 0.0 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'choose_pivot' in 0.0 secs
# Finished 'next_direction' in 0.0 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'choose_pivot' in 0.0 secs
# Finished 'next_direction' in 0.0 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'next_direction' in 0.0 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'next_direction' in 0.0 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'next_direction' in 0.0 secs
# Finished 'next_factor' in 0.0 secs
# ...

# %%
# %%time
n=100
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(10):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,fast_lst_sq=False))
# Out:
# Finished 'next_direction' in 0.03 secs
# Finished 'next_direction' in 0.011 secs
# Finished 'next_direction' in 0.006 secs
# Finished 'next_direction' in 0.009 secs
# Finished 'next_direction' in 0.006 secs
# Finished 'next_direction' in 0.025 secs
# Finished 'next_direction' in 0.007 secs
# Finished 'next_direction' in 0.005 secs
# Finished 'next_direction' in 0.005 secs
# Finished 'next_direction' in 0.094 secs
# Finished 'next_direction' in 0.005 secs
# Finished 'next_direction' in 0.004 secs
# Finished 'next_direction' in 0.005 secs
# Finished 'next_direction' in 0.005 secs
# Finished 'next_direction' in 0.005 secs
# Finished 'next_direction' in 0.011 secs
# Finished 'next_direction' in 0.007 secs
# Finished 'next_direction' in 0.004 secs
# Finished 'next_direction' in 0.004 secs
# Finished 'next_direction' in 0.004 secs
# Finished 'next_direction' in 0.004 secs
# Finished 'next_direction' in 0.004 secs
# Finished 'next_direction' in 0.004 secs
# ...

# %%
# %%time
n=100
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(10):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,fast_lst_sq=True))
# Out:
# Finished 'next_direction' in 0.01 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.006 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.011 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# ...

# %%
# %%time
n=100
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(10):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=True,flag_issue=True))
# Out:
# Finished 'next_direction' in 0.04 secs
# Finished 'next_direction' in 0.01 secs
# Finished 'next_direction' in 0.01 secs
# Finished 'next_direction' in 0.009 secs
# Finished 'next_direction' in 0.024 secs
# Finished 'next_direction' in 0.008 secs
# Finished 'next_direction' in 0.008 secs
# Finished 'next_direction' in 0.008 secs
# Finished 'next_direction' in 0.008 secs
# Finished 'next_direction' in 0.008 secs
# Finished 'next_direction' in 0.106 secs
# Finished 'next_direction' in 0.008 secs
# Finished 'next_direction' in 0.008 secs
# Finished 'next_direction' in 0.008 secs
# Finished 'next_direction' in 0.008 secs
# Finished 'next_direction' in 0.007 secs
# Finished 'next_direction' in 0.007 secs
# Finished 'next_direction' in 0.007 secs
# Finished 'next_direction' in 0.007 secs
# Finished 'next_direction' in 0.007 secs
# Finished 'next_direction' in 0.007 secs
# Finished 'next_direction' in 0.007 secs
# Finished 'next_direction' in 0.03 secs
# ...

# %%
# %%time
n=100
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(10):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=True,flag_issue=False))
# Out:
# Finished 'next_direction' in 0.023 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.001 secs
# Finished 'next_direction' in 0.001 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.014 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.008 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.001 secs
# Finished 'next_direction' in 0.001 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.004 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.001 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.002 secs
# Finished 'next_direction' in 0.001 secs
# Finished 'next_direction' in 0.001 secs
# Finished 'next_direction' in 0.001 secs
# Finished 'next_direction' in 0.001 secs
# ...

# %%
# %%time
n=200
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(n):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,fast_lst_sq=False))
# Out:
# C:\Users\Ga Bo\Desktop\Master Thesis\GSWalk\gsw.py:215: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   u1=np.linalg.lstsq(B_t,-B[:,p])[0]
# Wall time: 23min 35s

# %%
# %%time
n=200
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(n):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,fast_lst_sq=True))
# Out:
# Wall time: 12min 5s

# %%
# %%time
n=200
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(n):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=True,flag_issue=False))
# Out:
# Wall time: 14min 27s

# %%
# %%time
n=500
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(10):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,fast_lst_sq=True))
# Out:
# Wall time: 9min 24s

# %%
# %%time
n=500
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(10):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=True,flag_issue=False))
# Out:
# Wall time: 11min 45s

# %%
# %%time
n=1000
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(1):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,fast_lst_sq=True))
# Out:
# Wall time: 9min 10s

# %%
# %%time
n=1000
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(1):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=True,flag_issue=False))
# Out:
# Wall time: 8min 18s

# %%
# %%time
n=2000
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(1):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,fast_lst_sq=True))
# Out:
# Wall time: 1h 25min 8s

# %%
# %%time
n=2000
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(1):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=True,flag_issue=False))
# Out:
# Wall time: 1h 22min 21s

# %%
# %%time
#Now with adapted code which should be faster
n=500
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(10):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,fast_lst_sq=True))
# Out:
# Wall time: 10min 49s

# %%
# %%time
#Now with adapted code which should be faster
n=500
v=sample_from_sphere(n)
v=sample_from_ball(n,d=n)
gsw_xs=[]
for i in range(10):
    gsw_xs.append(gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=True,flag_issue=False))
# Out:
# Wall time: 11min 58s

# %%
A=np.array([[0,2],[1,0],[-1,-1]])
B=A.T.dot(A)
C=np.linalg.inv(B)
print(C)
# Out:
# [[ 0.55555556 -0.11111111]
#  [-0.11111111  0.22222222]]

# %%
n=10**3
v=sample_from_ball(n,d=n)
x=gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=True,flag_issue=False)
# Out:
# Finished 'sample_from_ball' in 0.087 secs
# Finished 'orthonormal_basis' in 0.013 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'choose_pivot' in 0.0 secs
# Time necessary to update C_S and D_S: 0.00022207700000365094
# Finished 'next_direction' in 2.553 secs
# Finished 'next_factor' in 0.001 secs
# Finished 'get_alives' in 0.0 secs
# Time necessary to update C_S and D_S: 0.07071925900000053
# Finished 'next_direction' in 0.079 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Time necessary to update C_S and D_S: 0.06993961900001011
# Finished 'next_direction' in 0.078 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Time necessary to update C_S and D_S: 0.08832532199998866
# Finished 'next_direction' in 0.098 secs
# Finished 'next_factor' in 0.001 secs
# Finished 'get_alives' in 0.0 secs
# Time necessary to update C_S and D_S: 0.07939228899999762
# Finished 'next_direction' in 0.087 secs
# ...

# %%
#new version
n=10**3
v=sample_from_ball(n,d=n)
x=gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=True,flag_issue=False)
# Out:
# Finished 'sample_from_ball' in 0.087 secs
# Finished 'orthonormal_basis' in 0.006 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'choose_pivot' in 0.0 secs
# C:\Users\Ga Bo\Desktop\Master Thesis\GSWalk\gsw.py:491: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   sol=np.linalg.lstsq(m, i)
# Time necessary to update C_S and D_S: 0.00025343799999966166
# Finished 'next_direction' in 2.753 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Time necessary to update C_S and D_S: 0.05565377099999935
# Finished 'next_direction' in 0.065 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Time necessary to update C_S and D_S: 0.053435553999999996
# Finished 'next_direction' in 0.063 secs
# ...

# %%
#newer version
n=10**3
v=sample_from_ball(n,d=n)
x=gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=True,flag_issue=False)
# Out:
# Finished 'sample_from_ball' in 0.089 secs
# Finished 'orthonormal_basis' in 0.015 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'choose_pivot' in 0.0 secs
# C:\Users\Ga Bo\Desktop\Master Thesis\GSWalk\gsw.py:516: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   sol=np.linalg.lstsq(m, i)
# Time necessary to update C_S and D_S: 0.00010538699999962375
# Finished 'next_direction' in 3.275 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Time necessary to update C_S and D_S: 0.03677833299999911
# Finished 'next_direction' in 0.046 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Time necessary to update C_S and D_S: 0.03663210500000069
# Finished 'next_direction' in 0.046 secs
# ...

# %%
n=10**3
v=sample_from_ball(n,d=n)
x=gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=False,flag_issue=False)
# Out:
# Finished 'sample_from_ball' in 0.052 secs
# Finished 'orthonormal_basis' in 0.003 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'choose_pivot' in 0.0 secs
# Time necessary to compute u_1 from X_t: 0.03351828800000334
# Finished 'next_direction' in 2.693 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Time necessary to update X_t: 0.026459964000004277
# Time necessary to compute u_1 from X_t: 0.03354016699999818
# Finished 'next_direction' in 0.071 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Time necessary to update X_t: 0.027039770000001795
# Time necessary to compute u_1 from X_t: 0.05025063000000074
# Finished 'next_direction' in 0.087 secs
# Finished 'next_factor' in 0.0 secs
# Finished 'get_alives' in 0.0 secs
# Time necessary to update X_t: 0.026834468000004108
# Time necessary to compute u_1 from X_t: 0.08774770299999801
# Finished 'next_direction' in 0.124 secs
# Finished 'next_factor' in 0.001 secs
# ...

# %%
n=3*10**3
v=sample_from_ball(n,d=n)
x=gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=True,flag_issue=False)
# Out:
# Finished 'sample_from_ball' in 0.562 secs
# Finished 'orthonormal_basis' in 0.075 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'choose_pivot' in 0.0 secs
# C:\Users\Ga Bo\Desktop\Master Thesis\GSWalk\gsw.py:517: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   sol=np.linalg.lstsq(m, i)
# Time necessary to update C_S and D_S: 0.00025052000000869157
# Finished 'next_direction' in 58.303 secs
# Finished 'next_factor' in 0.001 secs
# Finished 'get_alives' in 0.001 secs
# Time necessary to update C_S and D_S: 0.431520472000102
# Finished 'next_direction' in 0.498 secs
# Finished 'next_factor' in 0.001 secs
# Finished 'get_alives' in 0.001 secs
# Time necessary to update C_S and D_S: 0.38004787199997736
# Finished 'next_direction' in 0.457 secs
# ...

# %%
n=3*10**3
v=sample_from_ball(n,d=n)
x=gram_schmidt_walk(v,np.zeros(n),plot=False,debug=False,no_matrix_mult=False,flag_issue=False)
# Out:
# Finished 'sample_from_ball' in 0.659 secs
# Finished 'orthonormal_basis' in 0.078 secs
# Finished 'get_alives' in 0.0 secs
# Finished 'choose_pivot' in 0.0 secs
# C:\Users\Ga Bo\Desktop\Master Thesis\GSWalk\gsw.py:517: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   sol=np.linalg.lstsq(m, i)
# Time necessary to compute u_1 from X_t: 0.8637564030000036
# Finished 'next_direction' in 51.394 secs
# Finished 'next_factor' in 0.001 secs
# Finished 'get_alives' in 0.001 secs
# Time necessary to update X_t: 0.33986034999999504
# Time necessary to compute u_1 from X_t: 0.8306334040000038
# Finished 'next_direction' in 1.261 secs
# Finished 'next_factor' in 0.001 secs
# Finished 'get_alives' in 0.001 secs
# Time necessary to update X_t: 0.33588192999999933
# ...
