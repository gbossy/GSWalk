# %%
from gsw import *

# %%
#Trying to see what's colored early in 2 dimension
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='random')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [50.22 49.82 49.66 53.12 46.78 48.56 54.5  47.82 51.14 49.17 53.48 47.41
#  47.96 43.11 49.24 53.45 46.27 53.11 49.62 53.31 51.31 51.96 47.96 51.
#  49.6  45.54 49.65 49.67 47.85 52.17 51.21 45.47 43.33 54.12 47.81 51.33
#  47.83 51.16 47.15 51.57 49.22 52.12 46.56 46.31 47.27 43.07 45.93 52.31
#  50.61 51.34 51.8  47.1  50.71 46.92 52.31 48.56 50.84 48.85 49.96 50.29
#  52.48 51.02 49.49 51.08 49.47 49.99 43.69 51.05 49.   45.42 49.73 49.09
#  49.18 47.32 46.92 48.32 49.78 44.83 47.56 48.15 52.39 55.92 50.38 54.86
#  52.77 52.95 47.99 46.55 47.46 50.33 50.66 42.91 51.28 50.23 56.04 48.66
#  51.97 55.33 46.77 43.46]

# %%
#Trying to see what's colored early in 2 dimension
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='random')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [47.02 48.41 47.77 54.44 50.41 41.76 49.4  50.01 49.01 48.98 46.14 49.3
#  52.67 45.26 48.68 47.3  48.69 51.69 49.51 46.76 51.43 48.82 49.33 51.87
#  52.1  48.54 48.69 49.44 51.22 50.15 45.32 50.97 55.12 50.53 48.11 49.66
#  48.56 46.15 53.78 54.65 49.79 52.86 50.93 45.96 48.95 46.76 48.25 45.97
#  43.85 47.29 48.57 50.41 48.39 42.94 52.79 48.46 55.85 52.25 51.56 47.22
#  47.91 51.18 51.29 53.1  44.83 50.38 51.61 52.48 49.47 52.73 46.52 51.35
#  47.72 48.64 49.4  51.8  52.39 51.35 47.01 52.54 45.87 48.75 52.04 49.32
#  53.39 45.97 48.79 53.02 47.29 55.35 51.68 54.94 49.06 48.51 49.27 47.16
#  40.28 45.07 49.78 54.06]

# %%
#Trying to see what's colored early in 2 dimension
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='random')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [51.33 54.09 46.96 53.31 45.91 50.07 49.14 47.71 49.57 48.49 50.21 47.28
#  43.48 52.56 52.85 46.19 52.2  48.37 49.58 53.34 45.05 49.6  47.44 47.54
#  48.63 48.69 53.36 44.1  51.93 48.07 50.34 49.48 47.77 51.69 44.71 55.14
#  49.83 48.44 49.33 50.79 47.08 51.42 46.79 46.73 48.54 47.82 48.77 48.84
#  44.78 55.23 45.44 51.18 52.22 48.35 46.47 47.94 49.29 50.76 47.14 53.54
#  51.93 52.96 50.19 50.57 49.31 50.71 50.62 50.85 40.64 44.39 45.97 52.28
#  52.69 50.84 44.77 57.6  45.93 47.97 52.09 48.5  52.08 48.35 50.87 52.1
#  53.59 50.98 49.6  46.91 51.55 46.77 50.35 51.25 55.11 49.73 48.39 46.83
#  50.63 52.53 48.33 50.34]

# %%
#Trying to see what's colored early in 2 dimension
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='max_coloring')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [57.88 54.43 51.82 53.47 48.64 41.29 40.93 54.98 51.93 40.59 39.18 46.85
#  43.47 48.94 43.78 43.14 47.49 47.25 49.1  45.81 41.98 56.48 49.57 47.97
#  41.73 53.8  56.55 43.28 46.03 42.88 41.95 51.63 53.82 53.64 41.15 54.02
#  58.38 49.45 45.29 46.23 39.96 45.26 55.76 53.87 52.79 54.51 53.5  46.93
#  56.83 45.49 56.82 51.52 47.18 47.24 44.87 48.12 55.58 44.18 42.56 49.66
#  44.28 55.27 51.76 54.33 39.07 49.04 53.73 51.65 43.24 42.26 48.69 52.59
#  57.31 54.4  52.91 56.5  48.3  53.31 55.39 45.65 55.93 51.64 48.53 55.58
#  48.77 43.74 41.88 53.63 56.57 56.53 57.14 46.19 44.93 55.91 44.92 53.17
#  48.46 52.01 58.99 46.37]

# %%
#Trying to see what's colored early in 2 dimension
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='max_coloring')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [56.9  51.38 46.84 53.62 59.16 62.89 38.47 48.87 59.04 57.3  56.82 60.72
#  33.01 31.09 56.79 49.25 53.   58.27 42.75 56.64 49.59 38.33 33.76 63.53
#  34.65 51.73 61.11 62.04 62.26 51.45 36.35 36.97 54.86 52.01 56.39 58.4
#  45.49 39.27 52.2  29.65 61.57 62.04 61.62 37.36 36.82 43.51 33.71 64.85
#  51.3  47.73 55.13 58.02 56.54 58.39 35.04 60.15 46.77 58.95 29.61 29.86
#  38.12 30.72 66.   33.24 55.92 57.52 32.83 33.53 54.09 65.92 64.77 57.15
#  43.56 34.94 55.81 50.05 50.93 59.78 61.66 58.85 40.35 37.29 30.12 44.43
#  60.87 28.51 58.6  59.05 36.2  53.87 42.42 38.01 55.11 56.77 57.03 59.74
#  44.31 43.09 54.6  52.42]

# %%
#Trying to see what's colored early in 2 dimension
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='max_coloring')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [52.13 57.12 49.16 33.05 49.17 58.63 42.19 56.8  32.01 33.53 52.75 64.87
#  33.08 51.6  38.01 55.63 53.77 58.69 60.03 56.01 37.12 57.81 55.08 56.28
#  52.75 56.09 44.29 59.88 35.87 31.83 31.57 54.8  60.89 38.22 41.04 31.74
#  44.39 49.73 37.49 48.3  53.89 47.54 59.09 54.64 34.57 49.34 46.11 52.88
#  55.09 52.89 32.84 33.85 59.73 52.88 33.86 35.51 63.37 41.58 51.93 54.11
#  65.31 51.7  54.3  48.18 48.   32.5  49.73 44.04 36.34 53.28 54.7  52.04
#  63.21 56.07 31.8  57.5  32.46 64.29 38.25 52.8  58.26 56.78 54.81 62.07
#  59.49 41.39 45.8  61.14 59.33 50.86 55.92 52.93 43.94 59.96 52.14 58.71
#  42.05 49.13 63.45 56.24]

# %%
#Trying to see what's colored early in 2 dimension now with an artificial hole in the circle
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
    if v[i][0]<-0.5 and v[i][1]<-0.5:
        v[i]=np.abs(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='max_coloring')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [52.07 46.57 57.31 48.91 44.55 39.8  47.19 47.74 47.35 47.35 51.56 42.73
#  51.45 52.59 48.6  46.52 45.44 45.38 51.65 50.03 44.72 52.11 51.96 56.17
#  50.65 55.53 42.82 55.58 45.97 48.18 48.84 50.23 58.93 50.2  54.82 56.82
#  50.04 47.94 60.47 52.81 58.99 43.1  57.42 49.56 45.73 38.5  37.11 47.64
#  42.6  55.5  55.69 45.46 44.91 48.88 58.16 49.19 44.69 56.12 47.92 54.03
#  46.11 40.35 56.91 44.83 50.71 51.43 50.19 44.11 47.87 48.44 50.59 46.17
#  55.14 50.88 56.57 54.31 57.38 48.67 48.35 52.9  47.46 45.75 43.2  45.98
#  47.41 46.28 58.71 46.05 51.32 47.69 48.93 51.06 56.14 44.02 51.52 40.02
#  49.26 44.14 47.14 55.23]

# %%
#Trying to see what's colored early in 2 dimension now with an artificial hole in the circle
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
    if v[i][0]<-0.5 and v[i][1]<-0.5:
        v[i]=np.abs(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='max_coloring')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [45.51 56.1  57.57 48.46 47.66 58.01 57.65 38.17 48.   55.97 58.8  43.61
#  53.19 47.34 46.05 49.67 56.03 50.29 59.6  43.3  42.76 45.09 54.93 58.68
#  45.81 60.99 39.35 53.85 48.16 45.21 55.17 50.3  47.79 54.53 50.03 60.46
#  54.76 41.83 41.44 58.95 50.49 43.99 47.98 61.45 48.   45.1  49.04 35.13
#  53.36 58.44 39.64 58.98 38.76 38.68 48.21 61.74 44.75 41.37 40.84 54.48
#  51.39 47.51 37.14 42.09 55.3  61.42 44.96 59.33 49.21 41.31 40.8  48.2
#  49.03 40.23 48.26 38.33 51.69 41.3  45.64 50.18 59.26 56.41 43.63 39.45
#  57.56 45.5  56.87 56.47 57.22 56.48 42.43 61.29 38.91 53.29 45.71 46.07
#  44.55 61.23 46.64 46.21]

# %%
#Trying to see what's colored early in 2 dimension now with an artificial hole in the circle
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
    if v[i][0]<-0.5 and v[i][1]<-0.5:
        v[i]=np.abs(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='max_coloring')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [44.76 48.09 57.24 57.62 46.6  46.93 55.93 46.1  42.39 55.79 46.35 52.99
#  54.34 48.95 47.83 49.34 48.91 43.04 41.61 47.32 56.35 51.03 46.12 58.21
#  46.61 43.91 45.86 42.51 52.72 55.16 48.91 42.27 48.89 43.6  51.92 43.69
#  47.99 47.7  49.78 48.94 48.36 46.12 53.06 53.18 52.24 55.6  49.22 52.47
#  44.89 45.47 49.22 47.82 52.29 50.67 52.61 50.94 55.81 45.95 49.63 56.25
#  46.   54.42 57.16 52.1  51.26 42.96 52.67 53.29 52.42 43.47 57.25 54.85
#  41.71 57.17 47.23 48.71 50.2  51.64 45.26 53.27 49.45 47.75 39.96 52.36
#  57.3  44.29 49.24 42.68 39.21 45.13 44.32 49.22 54.01 51.78 57.6  45.28
#  45.54 55.74 48.92 51.08]

# %%
#Trying to see what's colored early in 2 dimension now with an artificial hole in the circle
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
    if v[i][0]<-0.5 and v[i][1]<-0.5:
        v[i]=np.abs(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='max_coloring')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [48.04 46.24 44.19 44.35 49.64 50.36 53.76 40.18 48.6  54.86 54.27 48.52
#  52.79 55.72 50.23 55.73 44.15 51.29 51.32 46.94 51.07 56.91 53.23 48.58
#  52.44 45.72 48.38 54.91 45.04 54.85 41.56 45.78 41.11 56.18 50.93 53.38
#  50.84 53.65 49.78 46.82 54.11 44.98 49.88 46.89 53.91 52.49 55.98 53.27
#  54.9  46.98 54.83 54.37 49.24 40.75 50.59 52.87 42.8  46.13 49.71 45.49
#  47.23 53.14 48.82 50.53 46.62 50.84 45.48 52.11 51.08 54.21 39.38 53.61
#  41.93 55.78 51.19 50.05 51.81 48.76 43.71 51.85 45.4  47.15 41.4  55.9
#  50.12 45.64 48.82 39.05 49.7  51.31 50.9  42.04 44.08 53.06 45.89 42.55
#  54.86 50.66 54.19 56.64]

# %%
#Trying to see what's colored early in 2 dimension now with an artificial hole in the circle
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
    if v[i][0]<-0.5 and v[i][1]<-0.5:
        v[i]=np.abs(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='max_coloring')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [50.22 52.1  51.42 49.15 51.55 46.02 49.79 46.38 41.6  54.81 50.06 48.7
#  48.81 45.28 48.98 44.41 50.6  45.68 49.18 48.95 52.56 47.93 49.64 42.84
#  48.35 40.6  50.8  53.3  42.89 48.8  55.65 48.88 42.19 51.05 53.16 41.87
#  53.66 51.12 50.3  52.72 49.23 56.59 51.98 57.19 52.64 52.07 54.09 47.75
#  49.23 48.72 47.73 48.71 54.42 54.07 47.25 52.56 43.12 51.04 48.19 54.69
#  47.85 52.12 52.1  45.72 51.89 50.59 49.84 48.99 50.36 51.98 54.96 45.18
#  47.21 48.47 54.46 57.36 48.44 51.58 50.88 48.14 45.63 47.77 47.23 43.9
#  44.62 52.35 51.79 48.43 51.62 53.53 52.17 40.46 48.61 50.13 44.   47.29
#  41.58 49.26 56.99 51.25]

# %%
#Trying to see what's colored early in 2 dimension now with an artificial hole in the circle
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
    if v[i][0]<-0.5 and v[i][1]<-0.5:
        v[i]=np.abs(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='max_coloring')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [40.29 49.23 56.08 53.61 61.28 52.62 56.03 52.39 40.07 40.33 43.6  55.5
#  57.4  38.79 42.14 55.   56.13 40.13 55.27 46.48 36.26 38.49 39.89 52.52
#  60.04 49.69 49.9  47.43 39.84 57.51 50.35 58.58 58.9  57.37 58.32 39.41
#  50.69 55.23 37.35 44.31 57.99 59.43 57.4  46.86 36.8  50.96 49.82 39.67
#  49.96 55.3  50.45 52.87 40.49 56.68 42.92 54.02 45.63 55.32 54.32 35.26
#  42.81 52.41 56.14 42.37 54.12 41.59 57.39 43.78 41.35 57.26 54.22 46.95
#  52.28 53.73 52.31 52.32 46.38 56.69 60.73 43.79 50.86 50.04 40.19 55.41
#  52.28 47.84 56.02 56.29 45.65 36.71 42.41 45.12 50.72 40.43 59.03 53.18
#  51.8  42.36 43.34 55.1 ]

# %%
#Trying to see what's colored early in 2 dimension now with an artificial hole in the circle
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
    if v[i][0]<-0.5 and v[i][1]<-0.5:
        v[i]=np.abs(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='max_coloring')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [46.66 54.26 46.94 42.99 50.71 47.61 46.85 53.76 47.6  48.83 49.93 54.94
#  49.75 50.62 47.01 49.52 47.67 49.36 52.17 45.22 42.12 46.82 55.42 46.99
#  51.25 52.86 50.14 51.08 47.69 50.49 47.34 48.24 51.64 47.51 49.2  45.38
#  50.95 49.25 49.8  45.9  52.1  53.52 44.19 47.27 53.07 48.3  57.24 42.28
#  42.55 52.55 48.58 51.06 46.87 48.03 53.88 50.28 52.12 45.49 51.61 48.78
#  49.25 47.15 54.44 56.33 49.29 51.83 54.04 51.81 44.57 46.69 46.96 48.59
#  41.02 56.4  50.73 49.79 55.18 39.85 49.96 44.27 54.72 51.16 47.68 49.35
#  54.23 48.11 52.96 52.4  50.14 51.23 51.51 50.78 46.9  49.48 48.85 48.28
#  50.39 50.44 48.74 52.26]

# %%
#Trying to see what's colored early in 2 dimension now with an artificial hole in the circle
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
    if v[i][0]<-0.5 and v[i][1]<-0.5:
        v[i]=np.abs(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='max_coloring')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [48.85 54.83 44.12 40.43 59.36 52.25 47.75 54.98 44.44 53.71 51.78 57.06
#  53.59 59.11 43.36 50.37 45.66 56.75 47.54 44.33 44.36 58.46 57.76 53.48
#  43.96 49.2  43.74 41.95 43.4  42.51 40.29 50.69 44.91 40.92 49.75 43.95
#  58.38 53.46 45.75 51.6  42.25 47.83 47.19 55.58 53.11 41.53 41.56 45.71
#  42.96 49.43 39.01 53.6  56.4  56.42 43.7  54.36 54.25 41.51 44.2  56.69
#  48.28 44.18 56.06 42.91 47.89 48.65 57.69 49.57 56.52 47.25 52.45 57.54
#  54.2  56.84 53.56 48.9  57.38 48.46 44.54 50.61 56.85 45.34 50.53 57.46
#  48.89 54.57 48.16 42.91 46.7  54.98 46.73 56.49 41.19 44.23 51.94 44.22
#  51.7  58.11 48.14 41.3 ]

# %%
#Trying to see what's colored early in 2 dimension now with an artificial hole in the circle
n=100
#v=sample_from_sphere(n,d=2)
v=sample_from_ball(n,d=2)
for i in range(len(v)):
    v[i]=normalize(v[i])
    if v[i][0]<-0.5 and v[i][1]<-0.5:
        v[i]=np.abs(v[i])
#print(f'v:{v}')
plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
B=np.transpose(np.vstack(tuple([e for e in v])))
gsw_xs=[]
when_colored=[]
for i in range(100):
    #print(i)
    x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='max_coloring')
    gsw_xs.append(x)
    switched_list=[(i,order[i]) for i in range(len(order))]
    switched_list.sort(key=lambda x:x[1])
    when_col=np.array([x[0] for x in switched_list])
    when_colored.append(when_col)
plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
ACT=average(when_colored)
print(ACT)
early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early')
late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late')
plt.legend()
plt.legend(bbox_to_anchor=(1.35, 1))
# Out:
# [45.46 48.6  44.94 45.31 45.76 43.24 49.03 50.06 52.17 50.27 50.02 46.88
#  50.87 50.72 52.92 44.58 46.97 49.52 50.8  52.82 50.29 46.44 49.78 56.34
#  47.21 52.   45.63 50.5  44.48 49.14 49.   54.94 50.93 47.59 47.83 54.43
#  55.96 47.74 47.69 47.44 42.01 44.4  54.84 47.36 49.3  51.2  53.34 54.82
#  51.54 49.34 49.5  53.64 44.99 48.53 47.37 45.3  54.49 48.77 45.34 54.82
#  47.41 49.61 48.25 50.74 42.62 48.   55.   48.6  54.09 52.11 50.22 48.09
#  53.57 51.95 50.07 49.11 45.77 45.73 45.63 49.3  48.51 56.66 47.63 49.26
#  54.05 47.51 52.68 48.46 50.49 55.11 46.86 46.06 54.68 47.81 47.16 49.3
#  51.21 49.75 56.29 47.45]

# %%
#No hole but looking at eigenvectors now:
#Trying to see what's colored early in 2 dimension
def run_experiment(n=100, det=False):
    #v=sample_from_sphere(n,d=2)
    v=sample_from_ball(n,d=2)
    for i in range(len(v)):
        v[i]=normalize(v[i])
    #print(f'v:{v}')
    plt.plot([e[0] for e in v],[e[1] for e in v],'o',label='other input vectors')
    B=np.transpose(np.vstack(tuple([e for e in v])))
    gsw_xs=[]
    when_colored=[]
    for i in range(n):
        #print(i)
        x,order=gram_schmidt_walk(v,np.zeros(n),plot=False,order=True,debug=False,no_matrix_mult=False,mode='max_coloring',pivot=i,smallest_delta=det)
        gsw_xs.append(x)
        switched_list=[(i,order[i]) for i in range(len(order))]
        switched_list.sort(key=lambda x:x[1])
        when_col=np.array([x[0] for x in switched_list])
        when_colored.append(when_col)
    plt.plot([np.matmul(B,x)[0] for x in gsw_xs],[np.matmul(B,x)[1] for x in gsw_xs],'o',label='Output sum of groups with GSW')
    ACT=average(when_colored)
    print(ACT)
    early_vs=[v[i] for i in range(len(v)) if ACT[i]<0.4*n]
    plt.plot([vec[0] for vec in early_vs],[vec[1] for vec in early_vs],'o',label=f'Early',markersize=16)
    late_vs=[v[i] for i in range(len(v)) if ACT[i]>0.6*n]
    plt.plot([vec[0] for vec in late_vs],[vec[1] for vec in late_vs],'o',label=f'Late',markersize=16)
    mat=sum([np.matmul(v[i].reshape((len(v[0]),1)),v[i].reshape((1,len(v[0])))) for i in range(len(v))])
    eig,v=np.linalg.eig(mat)
    #i=np.argmax(eig)
    for i in range(2):
        plt.plot(v[i][0],v[i][1],'o',label=f'Eigenvec of {eig[i]}',markersize=16)
    plt.legend()
    plt.legend(bbox_to_anchor=(1.35, 1))
    plt.show()

# %%
run_experiment()
# Out:
# [48.53 67.05 50.38 50.99 62.6  28.35 35.12 52.78 37.54 61.23 39.22 44.98
#  59.14 30.13 66.48 38.05 42.77 25.88 62.75 63.71 33.45 65.56 50.51 64.67
